# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("netflix_dataset_50.csv")

# %%
df.head(2)
# Out:
#      title    genre  release_year  rating content_type   views  watch_time  \
# 0  Title_1   Horror          2016     8.1        Movie  318824         157
# 1  Title_2  Romance          2024     6.5       Series  258426          68
#
#   country  region  genre_encoded
# 0   India  Europe              3
# 1     USA  Europe              4

# %% [markdown]
# # Year-wise aur month-wise release count

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          50 non-null     object
#  1   genre          50 non-null     object
#  2   release_year   50 non-null     datetime64[ns]
#  3   rating         50 non-null     float64
#  4   content_type   50 non-null     object
#  5   views          50 non-null     int64
#  6   watch_time     50 non-null     int64
#  7   country        50 non-null     object
#  8   region         50 non-null     object
#  9   genre_encoded  50 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 4.0+ KB

# %%
df['release_year'] = pd.to_datetime(df['release_year'], format='%Y')

# %%
df['month_name'] = df['release_year'].dt.month_name()

# %%
df.head(2)
# Out:
#      title    genre release_year  rating content_type   views  watch_time  \
# 0  Title_1   Horror   2016-01-01     8.1        Movie  318824         157
# 1  Title_2  Romance   2024-01-01     6.5       Series  258426          68
#
#   country  region  genre_encoded month_name
# 0   India  Europe              3    January
# 1     USA  Europe              4    January

# %%
df['month_name'].unique()
# Out:
# array(['January'], dtype=object)

# %% [markdown]
# # Seasonal pattern (kab zyada release hote hain) find karna.

# %%
df['release_year']

# %% [markdown]
# # Emerging/new trending genres highlight karna.

# %%
result = df.groupby(['release_year', 'genre']).size().reset_index(name='highlight')
result
# Out:
#    release_year        genre  highlight
# 0    2015-01-01        Drama          1
# 1    2015-01-01       Horror          2
# 2    2015-01-01      Romance          1
# 3    2016-01-01       Action          1
# 4    2016-01-01       Comedy          3
# 5    2016-01-01  Documentary          1
# 6    2016-01-01       Horror          2
# 7    2017-01-01       Comedy          1
# 8    2017-01-01       Horror          1
# 9    2017-01-01      Romance          1
# 10   2018-01-01       Comedy          1
# 11   2018-01-01        Drama          2
# 12   2018-01-01       Horror          1
# 13   2018-01-01      Romance          1
# 14   2019-01-01        Drama          1
# 15   2019-01-01       Horror          1
# 16   2019-01-01      Romance          1
# 17   2020-01-01  Documentary          2
# 18   2020-01-01      Romance          1
# 19   2021-01-01       Action          1
# 20   2021-01-01        Drama          1
# 21   2021-01-01       Horror          1
# ...

# %%
df.head()
# Out:
#      title    genre release_year  rating content_type   views  watch_time  \
# 0  Title_1   Horror   2016-01-01     8.1        Movie  318824         157
# 1  Title_2  Romance   2024-01-01     6.5       Series  258426          68
# 2  Title_3    Drama   2023-01-01     9.3        Movie  178789         111
# 3  Title_4  Romance   2024-01-01     6.9        Movie  514153         133
# 4  Title_5  Romance   2019-01-01     9.2        Movie  743452         158
#
#   country         region  genre_encoded month_name
# 0   India         Europe              3    January
# 1     USA         Europe              4    January
# 2     USA         Europe              2    January
# 3  Canada  North America              4    January
# 4   India  North America              4    January
